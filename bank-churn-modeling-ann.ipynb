# %% [markdown]
# <a href="https://www.kaggle.com/code/avinashrola/bank-churn-modeling-ann?scriptVersionId=107810386" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/churn-modelling-data/Churn_Modelling.csv

# %%
data = pd.read_csv('/kaggle/input/churn-modelling-data/Churn_Modelling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.drop(['RowNumber','CustomerId','Surname'], axis=1, inplace=True)
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
data['Geography'] = le.fit_transform(data['Geography'])

data.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
x = data.drop('Exited', axis=1)
y = data['Exited']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.23)

# %%
sc = StandardScaler()
sc.fit_transform(x_train)
sc.transform(x_test)
# Out:
# array([[-0.71729128, -0.90415045,  0.9121539 , ...,  0.63708644,
#          0.9723307 , -0.45727824],
#        [-0.04845053, -0.90415045, -1.09630622, ..., -1.56964572,
#         -1.02845668,  0.52174101],
#        [-0.70700142,  0.2968084 , -1.09630622, ...,  0.63708644,
#          0.9723307 , -1.39722717],
#        ...,
#        [-1.03627687,  0.2968084 ,  0.9121539 , ...,  0.63708644,
#          0.9723307 , -1.024806  ],
#        [ 0.69241922,  0.2968084 ,  0.9121539 , ...,  0.63708644,
#         -1.02845668, -1.17685204],
#        [ 0.68212937, -0.90415045,  0.9121539 , ...,  0.63708644,
#          0.9723307 ,  0.41874559]])

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
# Out:
# 2022-10-12 06:05:36.500498: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.add(Dense(units=20, activation = 'relu'))

# %%
model.add(Dense(units=20, activation = 'relu'))

# %%
model.add(Dense(units=1,activation = 'sigmoid'))

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 10, epochs = 100)
# Out:
# 2022-10-12 06:05:36.740887: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 770/770 [==============================] - 2s 2ms/step - loss: 189.5438 - accuracy: 0.6714
# Epoch 2/100
# 770/770 [==============================] - 2s 2ms/step - loss: 130.9644 - accuracy: 0.6645
# Epoch 3/100
# 770/770 [==============================] - 2s 2ms/step - loss: 111.2749 - accuracy: 0.6779
# Epoch 4/100
# 770/770 [==============================] - 2s 2ms/step - loss: 108.3637 - accuracy: 0.6768
# Epoch 5/100
# 770/770 [==============================] - 2s 2ms/step - loss: 101.9031 - accuracy: 0.6768
# Epoch 6/100
# 770/770 [==============================] - 2s 2ms/step - loss: 94.5718 - accuracy: 0.6809
# Epoch 7/100
# 770/770 [==============================] - 2s 2ms/step - loss: 81.5699 - accuracy: 0.6784
# Epoch 8/100
# 770/770 [==============================] - 2s 2ms/step - loss: 81.1785 - accuracy: 0.6817
# Epoch 9/100
# 770/770 [==============================] - 2s 2ms/step - loss: 85.8281 - accuracy: 0.6816
# Epoch 10/100
# 770/770 [==============================] - 2s 2ms/step - loss: 87.3605 - accuracy: 0.6710
# Epoch 11/100
# 770/770 [==============================] - 2s 2ms/step - loss: 67.5728 - accuracy: 0.6777
# Epoch 12/100
# 770/770 [==============================] - 2s 2ms/step - loss: 60.1497 - accuracy: 0.6792
# Epoch 13/100
# 770/770 [==============================] - 2s 2ms/step - loss: 68.1814 - accuracy: 0.6858
# Epoch 14/100
# 770/770 [==============================] - 2s 2ms/step - loss: 62.7917 - accuracy: 0.6795
# Epoch 15/100
# 770/770 [==============================] - 2s 2ms/step - loss: 66.8534 - accuracy: 0.6825
# Epoch 16/100
# 770/770 [==============================] - 2s 2ms/step - loss: 49.6515 - accuracy: 0.6816
# Epoch 17/100
# 770/770 [==============================] - 2s 2ms/step - loss: 60.2789 - accuracy: 0.6856
# Epoch 18/100
# 770/770 [==============================] - 2s 2ms/step - loss: 53.4443 - accuracy: 0.6791
# Epoch 19/100
# 770/770 [==============================] - 2s 2ms/step - loss: 44.3561 - accuracy: 0.6868
# Epoch 20/100
# 770/770 [==============================] - 1s 2ms/step - loss: 37.2307 - accuracy: 0.6862
# Epoch 21/100
# 770/770 [==============================] - 2s 2ms/step - loss: 40.5700 - accuracy: 0.6787
# Epoch 22/100
# 770/770 [==============================] - 2s 2ms/step - loss: 41.9474 - accuracy: 0.6875
# Epoch 23/100
# 770/770 [==============================] - 1s 2ms/step - loss: 34.6652 - accuracy: 0.6925
# Epoch 24/100
# 770/770 [==============================] - 1s 2ms/step - loss: 30.2462 - accuracy: 0.6768
# Epoch 25/100
# 770/770 [==============================] - 2s 2ms/step - loss: 30.7836 - accuracy: 0.6804
# Epoch 26/100
# 770/770 [==============================] - 1s 2ms/step - loss: 43.8692 - accuracy: 0.6882
# Epoch 27/100
# 770/770 [==============================] - 1s 2ms/step - loss: 30.7436 - accuracy: 0.6886
# Epoch 28/100
# 770/770 [==============================] - 1s 2ms/step - loss: 36.5386 - accuracy: 0.6903
# Epoch 29/100
# 770/770 [==============================] - 1s 2ms/step - loss: 29.2701 - accuracy: 0.6851
# Epoch 30/100
# 770/770 [==============================] - 1s 2ms/step - loss: 27.6381 - accuracy: 0.6865
# Epoch 31/100
# 770/770 [==============================] - 2s 2ms/step - loss: 26.4922 - accuracy: 0.6861
# Epoch 32/100
# 770/770 [==============================] - 2s 2ms/step - loss: 25.6889 - accuracy: 0.6903
# Epoch 33/100
# 770/770 [==============================] - 2s 2ms/step - loss: 23.1011 - accuracy: 0.6931
# Epoch 34/100
# 770/770 [==============================] - 1s 2ms/step - loss: 29.2505 - accuracy: 0.6903
# Epoch 35/100
# 770/770 [==============================] - 1s 2ms/step - loss: 24.6608 - accuracy: 0.6931
# Epoch 36/100
# 770/770 [==============================] - 2s 2ms/step - loss: 22.7212 - accuracy: 0.6939
# Epoch 37/100
# 770/770 [==============================] - 1s 2ms/step - loss: 23.8836 - accuracy: 0.6918
# Epoch 38/100
# 770/770 [==============================] - 1s 2ms/step - loss: 28.1569 - accuracy: 0.6870
# Epoch 39/100
# 770/770 [==============================] - 1s 2ms/step - loss: 17.1004 - accuracy: 0.6895
# Epoch 40/100
# 770/770 [==============================] - 1s 2ms/step - loss: 21.6879 - accuracy: 0.6939
# Epoch 41/100
# 770/770 [==============================] - 2s 2ms/step - loss: 24.0124 - accuracy: 0.6817
# Epoch 42/100
# 770/770 [==============================] - 1s 2ms/step - loss: 18.9030 - accuracy: 0.6812
# Epoch 43/100
# 770/770 [==============================] - 1s 2ms/step - loss: 17.5452 - accuracy: 0.6849
# Epoch 44/100
# 770/770 [==============================] - 2s 2ms/step - loss: 13.0211 - accuracy: 0.6944
# Epoch 45/100
# 770/770 [==============================] - 2s 2ms/step - loss: 14.5656 - accuracy: 0.6908
# Epoch 46/100
# 770/770 [==============================] - 2s 2ms/step - loss: 14.3653 - accuracy: 0.6805
# Epoch 47/100
# 770/770 [==============================] - 2s 2ms/step - loss: 12.3504 - accuracy: 0.6819
# Epoch 48/100
# 770/770 [==============================] - 2s 2ms/step - loss: 10.4562 - accuracy: 0.6840
# Epoch 49/100
# 770/770 [==============================] - 1s 2ms/step - loss: 10.0416 - accuracy: 0.6791
# Epoch 50/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.0135 - accuracy: 0.6817
# Epoch 51/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.5682 - accuracy: 0.6806
# Epoch 52/100
# 770/770 [==============================] - 2s 2ms/step - loss: 7.1063 - accuracy: 0.6830
# Epoch 53/100
# 770/770 [==============================] - 2s 2ms/step - loss: 6.0013 - accuracy: 0.6792
# Epoch 54/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.9108 - accuracy: 0.6869
# Epoch 55/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.1875 - accuracy: 0.6990
# Epoch 56/100
# 770/770 [==============================] - 2s 2ms/step - loss: 2.9526 - accuracy: 0.7190
# Epoch 57/100
# 770/770 [==============================] - 1s 2ms/step - loss: 2.1727 - accuracy: 0.7201
# Epoch 58/100
# 770/770 [==============================] - 1s 2ms/step - loss: 1.0726 - accuracy: 0.7366
# Epoch 59/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.8818 - accuracy: 0.7529
# Epoch 60/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.6120 - accuracy: 0.7799
# Epoch 61/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7896
# Epoch 62/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7903
# Epoch 63/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5096 - accuracy: 0.7969
# Epoch 64/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.7969
# Epoch 65/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5050 - accuracy: 0.7969
# Epoch 66/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5051 - accuracy: 0.7969
# Epoch 67/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5050 - accuracy: 0.7969
# Epoch 68/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5052 - accuracy: 0.7969
# Epoch 69/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5079 - accuracy: 0.7969
# Epoch 70/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5049 - accuracy: 0.7969
# Epoch 71/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5049 - accuracy: 0.7969
# Epoch 72/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5050 - accuracy: 0.7969
# Epoch 73/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5051 - accuracy: 0.7969
# Epoch 74/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5051 - accuracy: 0.7969
# Epoch 75/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5050 - accuracy: 0.7969
# Epoch 76/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5049 - accuracy: 0.7969
# Epoch 77/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 78/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5049 - accuracy: 0.7969
# Epoch 79/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.7969
# Epoch 80/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.7969
# Epoch 81/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5051 - accuracy: 0.7968
# Epoch 82/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5047 - accuracy: 0.7969
# Epoch 83/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5049 - accuracy: 0.7969
# Epoch 84/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 85/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5046 - accuracy: 0.7969
# Epoch 86/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 87/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5049 - accuracy: 0.7969
# Epoch 88/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.5049 - accuracy: 0.7968
# Epoch 89/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 90/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5047 - accuracy: 0.7969
# Epoch 91/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 92/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5047 - accuracy: 0.7969
# Epoch 93/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5047 - accuracy: 0.7969
# Epoch 94/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 95/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 96/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5047 - accuracy: 0.7969
# Epoch 97/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 98/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5047 - accuracy: 0.7969
# Epoch 99/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969
# Epoch 100/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.5048 - accuracy: 0.7969

# %%
model.save("ANN.h5")
